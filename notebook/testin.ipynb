# %%
from data_transformation import DataCleaning
from data_transformation import DataTransformation
from model_trainer import ModelTrainer

# %%
import pandas as pd

# %%
df = pd.read_csv('dubai_data.csv')

# %%
df.head()
# Out:
#         id          neighborhood  ...  view_of_water  walk_in_closet
# 0  5528049         Palm Jumeirah  ...           True           False
# 1  6008529         Palm Jumeirah  ...           True           False
# 2  6034542  Jumeirah Lake Towers  ...           True            True
# 3  6326063       Culture Village  ...          False           False
# 4  6356778         Palm Jumeirah  ...           True           False
#
# [5 rows x 38 columns]

# %%
data_cleaning = DataCleaning(df)

# %%
df = data_cleaning.data_cleaning(['id', 'price_per_sqft'])

# %%
finally_cleaned = DataTransformation(df)

# %%
X, y = finally_cleaned.data_transformation()

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1893 entries, 0 to 1904
# Data columns (total 35 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   latitude             1893 non-null   float64
#  1   longitude            1893 non-null   float64
#  2   size_in_sqft         1893 non-null   int64
#  3   no_of_bedrooms       1893 non-null   int64
#  4   no_of_bathrooms      1893 non-null   int64
#  5   quality              1893 non-null   int64
#  6   maid_room            1893 non-null   int64
#  7   unfurnished          1893 non-null   int64
#  8   balcony              1893 non-null   int64
#  9   barbecue_area        1893 non-null   int64
#  10  built_in_wardrobes   1893 non-null   int64
#  11  central_ac           1893 non-null   int64
#  12  childrens_play_area  1893 non-null   int64
#  13  childrens_pool       1893 non-null   int64
#  14  concierge            1893 non-null   int64
# ...

# %%
X.head()
# Out:
#     latitude  longitude  ...  walk_in_closet  neighborhood_price
# 0  25.113208  55.138932  ...               0        4.391594e+06
# 1  25.106809  55.151201  ...               0        4.391594e+06
# 2  25.063302  55.137728  ...               1        1.002028e+06
# 3  25.227295  55.341761  ...               0        3.677445e+06
# 4  25.114275  55.139764  ...               0        4.391594e+06
#
# [5 rows x 35 columns]

# %%
model_training = ModelTrainer(X, y)

# %%
best_model_name, model_details = model_training.model_trainer()
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [CV] END .................................fit_intercept=True; total time=   0.0s
# [CV] END .................................fit_intercept=True; total time=   0.0s
# [CV] END .................................fit_intercept=True; total time=   0.0s
# [CV] END .................................fit_intercept=True; total time=   0.0s
# [CV] END .................................fit_intercept=True; total time=   0.0s
# [CV] END ................................fit_intercept=False; total time=   0.0s
# [CV] END ................................fit_intercept=False; total time=   0.0s
# [CV] END ................................fit_intercept=False; total time=   0.0s
# [CV] END ................................fit_intercept=False; total time=   0.0s
# [CV] END ................................fit_intercept=False; total time=   0.0s
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# ...

# %%
print(best_model_name)
print(model_details)
# Out:
# RandomForestRegressor
# {'best_params': {'criterion': 'friedman_mse', 'max_depth': 20, 'max_features': 'log2', 'n_estimators': 100}, 'best_score': 1551621046154.2954, 'mse': 719672140710.0366}

# %%
import os 
import pandas as pd

# %%
class DataFiles:
    def __init__(self, raw_data_file_path):
        self.raw_data = pd.read_csv(raw_data_file_path)

    def

# %%
os_main_dir = '/Users/harish_daga/Desktop/dubai_analysis'

# %%
csv_file_path = os_main_dir+'/dubai_data.csv'

# %%
df = pd.read_csv(csv_file_path)

# %%
df
# Out:
#            id                       neighborhood  ...  view_of_water  walk_in_closet
# 0     5528049                      Palm Jumeirah  ...           True           False
# 1     6008529                      Palm Jumeirah  ...           True           False
# 2     6034542               Jumeirah Lake Towers  ...           True            True
# 3     6326063                    Culture Village  ...          False           False
# 4     6356778                      Palm Jumeirah  ...           True           False
# ...       ...                                ...  ...            ...             ...
# 1900  7705450           Mohammed Bin Rashid City  ...           True            True
# 1901  7706287           Mohammed Bin Rashid City  ...           True            True
# 1902  7706389  Dubai Creek Harbour (The Lagoons)  ...          False           False
# 1903  7706591            Jumeirah Village Circle  ...           True            True
# ...
